# %%
import requests
from datetime import datetime

key = '7VzerKN0HQtsXy9GGvWPGpG2N5TrLcGd'

url = f'https://app.ticketmaster.com/discovery/v2/events.json?dmaId=235&apikey={key}'

start_date = datetime(2024,11,1)
end_date = datetime(2025,2,28)
response = requests.get(url)

if response.status_code == 200:
    data = response.json()
    events = data.get('_embedded',{}).get('events',[])

    events_by_month = {}

    if events:
        for event in events:
            name = event.get('name','N/A')
            date_str = event.get('dates',{}).get('start',{}).get('localDate','N/A')
            venue = event.get('_embedded',{}).get('venues',[{}])[0].get('name','N/A')

            event_date=datetime.strptime(date_str, '%Y-%m-%d')

            if start_date <= event_date <= end_date:
                month = event_date.strftime('%B %Y')
                if month not in events_by_month:
                    events_by_month[month] = []
                events_by_month[month].append({
                    'name': name,
                    'date': date_str,
                    'venue': venue})

        for month, month_events in events_by_month.items():
            print(f"events in {month}: \n")
            for event in month_events:
                print(f"event name: {event['name']}")
                print(f"event nate: {event['date']}")
                print(f"venue: {event['venue']}")
                print("\n")
# Out:
# events in November 2024:
#
# event name: Boston Bruins vs. Ottawa Senators
# event nate: 2024-11-09
# venue: TD Garden
#
#
# event name: Boston Bruins vs. Seattle Kraken
# event nate: 2024-11-03
# venue: TD Garden
#
#
# event name: Boston Bruins vs. St. Louis Blues
# event nate: 2024-11-16
# venue: TD Garden
#
#
# event name: Boston Bruins vs. Pittsburgh Penguins
# event nate: 2024-11-29
# venue: TD Garden
#
#
# event name: The Spinners - Evelyn Champagne King - Rose Royce
# event nate: 2024-11-09
# venue: Lynn Auditorium
#
#
# event name: Boston Bruins vs. Vancouver Canucks
# event nate: 2024-11-26
# venue: TD Garden
#
#
# event name: Boston Bruins vs. Calgary Flames
# event nate: 2024-11-07
# venue: TD Garden
#
#
# events in December 2024:
#
# event name: Boston Bruins vs. Montreal Canadiens
# event nate: 2024-12-01
# venue: TD Garden
#
#
# event name: Disney On Ice presents Into the Magic
# event nate: 2024-12-21
# venue: Cross Insurance Arena
#
#
# event name: Disney On Ice presents Into the Magic
# event nate: 2024-12-21
# venue: Cross Insurance Arena
#
#
# event name: Boston Bruins vs. Philadelphia Flyers
# event nate: 2024-12-07
# venue: TD Garden
#
#
# events in January 2025:
#
# event name: Disney On Ice presents Into the Magic
# event nate: 2025-01-04
# venue: XL CENTER
#
#
# event name: Disney On Ice presents Into the Magic
# event nate: 2025-01-04
# venue: XL CENTER
